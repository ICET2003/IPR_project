# %%
# Install packages
# !pip install spacy
# !python -m spacy download en_core_web_sm

# %%
# Test with a limited set of trees
import pandas as pd
import spacy
from spacy.matcher import PhraseMatcher

# Load model
nlp = spacy.load("en_core_web_sm") # English model

# Load your Excel data
df = pd.read_excel("MCDC Sample Info-2.xlsx")
descriptions = df["Project Description"].fillna("")

# USDA-based species list (expandable)
usda_species = [
    "Red Maple", "Sugar Maple", "Silver Maple", "White Oak", "Bur Oak", "Northern Red Oak",
    "Pin Oak", "Eastern Redbud", "Serviceberry", "Dogwood", "Black Walnut", "Bald Cypress",
    "Ginkgo", "River Birch", "Honeylocust", "Eastern White Pine", "Loblolly Pine",
    "Shortleaf Pine", "American Beech", "American Elm", "Black Cherry", "Tulip Tree",
    "Hackberry", "Hickory", "Kentucky Coffeetree", "Sweetgum", "Sycamore", "Persimmon",
    "Apple", "Peach", "Plum", "Pear", "Cherry", "Granny Smith", "Honeycrisp", "Jonathan",
    "Fuji", "Stella", "Lapins", "Harvester", "Majestic", "Rome Beauty"
]

# Setup spaCy matcher
matcher = PhraseMatcher(nlp.vocab, attr="LOWER")
patterns = [nlp.make_doc(name) for name in usda_species]
matcher.add("USDA_TREE_SPECIES", patterns)

# Extraction function
def extract_species(text):
    doc = nlp(text)
    matches = matcher(doc)
    return list(set(doc[start:end].text for _, start, end in matches))

# Apply to your dataset
df["USDA Matched Species"] = descriptions.apply(extract_species)

# Save to CSV
df.to_csv("usda_species_extracted.csv", index=False)

# %%
descriptions

# %%
# Get a list of species from USDA plant list
# This function reads the USDA plant list file and extracts species names.
df_plant_list = pd.read_csv("plant_checklist.txt")

# %%
df_plant_list

# %%
# Cut Author out of scientific names if present
def clean_scientific_name(name):
    if pd.isna(name):
        return None
    return " ".join(name.split()[:2]) # Keep only the first two parts (genus and species)
df_plant_list['clean_scientific_name'] = df_plant_list['Scientific Name with Author'].apply(clean_scientific_name)

# %%
# Combine all names into one list for matching
name_set = pd.concat([
    df_plant_list["clean_scientific_name"].dropna(),
    df_plant_list["Common Name"].dropna()
]).str.lower().unique().tolist()

# %%
import pandas as pd
import spacy
from spacy.matcher import PhraseMatcher

# Load model
nlp = spacy.load("en_core_web_sm") # English model

# Load your Excel data
df = pd.read_excel("MCDC Sample Info-2.xlsx")
descriptions = df["Project Description"].fillna("")

# USDA-based species list (expandable)
# Already defined in the previous section, but can be expanded as needed

# Setup spaCy matcher
matcher = PhraseMatcher(nlp.vocab, attr="LOWER")
patterns = [nlp.make_doc(name) for name in name_set]
matcher.add("USDA_TREE_SPECIES", patterns)

# Extraction function
def extract_species(text):
    doc = nlp(text)
    matches = matcher(doc)
    return list(set(doc[start:end].text for _, start, end in matches))

# Apply to your dataset
df["USDA Matched Species"] = descriptions.apply(extract_species)

# Save to CSV
df.to_csv("usda_species_extracted.csv", index=False)

# %%
# !pip install openai

# %%
# Install Gemini
# !pip install google-generativeai

# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyAPP-Ou6h2V_d8zSKjSLiJnDs1YJo7YyUo")

models = genai.list_models()
for m in models:
    print(m.name)

# %%
# Import google generative AI
import google.generativeai as genai

# Set up the API key
genai.configure(api_key= "AIzaSyAPP-Ou6h2V_d8zSKjSLiJnDs1YJo7YyUo")

# Initialize the Gemini model
model = genai.GenerativeModel('gemini-1.5-flash')

# Send a prompt, engineering it until returning a Python dictionary
response = model.generate_content("Extract the species and tree counts from this description. "
    "Respond ONLY as a Python dictionary, e.g., {'Red Maple': 3, 'Honeycrisp apple': 4}, no extra text. "
    f"Description: 'We will plant 3 Red Maple and 4 Honeycrisp apple trees.'")

print(response.text)

# %%
#Parse the response to extract species and counts
import re

def parse_gemini_response(text):
    result = []
    # Split lines
    lines = text.split('\n')
    return lines

# %%
# Start extract species and tree counts from the descriptions from df
# We need the result to be a list of dictionaries with species and counts
def extract_species_and_counts(description):
    # Send the description to Gemini
    response = model.generate_content("Extract the species and tree counts from this description. "
    "Respond ONLY as a Python dictionary, e.g., {'Red Maple': 3, 'Honeycrisp apple': 4}, no extra text. "
    f"Description: '{description}'")
    
    # Parse the response
    text = response.text.strip()
    
    return text

# %%
extract_species_and_counts("Planting 3 Red Maple and 4 Honeycrisp apple trees.")

# %%
# Next, we will add the result to a new column in a csv file
import pandas as pd
# Load the existing CSV file
df = pd.read_csv("usda_species_extracted.csv")
# Add a new column for the Gemini response
df["Species from Gemini Response"] = df["Project Description"].apply(extract_species_and_counts)
# Save the updated DataFrame to a new CSV file
df.to_csv("usda_species_extracted_with_gemini.csv", index=False)

# %%
# Install ollama
# !pip install ollama
# Out:
# Requirement already satisfied: ollama in /opt/anaconda3/lib/python3.11/site-packages (0.5.1)
# Requirement already satisfied: httpx>=0.27 in /opt/anaconda3/lib/python3.11/site-packages (from ollama) (0.27.0)
# Requirement already satisfied: pydantic>=2.9 in /opt/anaconda3/lib/python3.11/site-packages (from ollama) (2.10.3)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.11/site-packages (from httpx>=0.27->ollama) (4.6.2)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.11/site-packages (from httpx>=0.27->ollama) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.11/site-packages (from httpx>=0.27->ollama) (1.0.2)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.11/site-packages (from httpx>=0.27->ollama) (3.7)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.11/site-packages (from httpx>=0.27->ollama) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic>=2.9->ollama) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic>=2.9->ollama) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic>=2.9->ollama) (4.12.2)

# %%
import ollama
import pandas as pd
import ast

# Load your CSV
df = pd.read_csv("usda_species_extracted.csv")

# Initialize Ollama client
model_name = 'mistral'  # You can also use 'llama3', 'gemma', etc.

# %%
import ollama
import pandas as pd
import ast

# Load your CSV
df = pd.read_csv("usda_species_extracted.csv")

# Initialize Ollama client
model_name = 'mistral'  # You can also use 'llama3', 'gemma', etc.

def extract_species_and_counts_ollama(description):
    prompt = (
        "Extract the species and tree counts from this description. "
        "Respond ONLY as a Python dictionary like {'Red Maple': 3, 'Honeycrisp apple': 4}. "
        "The {'Red Maple': 3, 'Honeycrisp apple': 4} is just an example. We do not need to include Red Maple and Honeycrisp apple in the dictionary if it does not exist in descriptions."
        "If no species founded, return an empty dictionary {}. "
        "If there are no specific counts for each kind of tree but there are total counts, divide the total counts equally among the species. "
        "No explanation, no code, no extra text.\n"
        f"Description: {description}"
    )

    response = ollama.chat(
        model=model_name,
        messages=[{'role': 'user', 'content': prompt}]
    )

    raw_text = response['message']['content'].strip()
    print("RAW RESPONSE:", raw_text)  # For debugging

    # Safely parse to Python dictionary
    try:
        result = ast.literal_eval(raw_text)
    except Exception as e:
        print(f"Parsing error: {e}")
        result = {}

    return result

# Apply all rows
df['Species from Ollama'] = df['Project Description'].apply(extract_species_and_counts_ollama)

# Save result
df.to_csv("usda_species_extracted_with_ollama.csv", index=False)

print("✅ Done! Saved to usda_species_extracted_with_ollama.csv")

# %%
# Next we will extract goals from the project goals
import pandas as pd
# Load the existing CSV file
df_2 = pd.read_csv("usda_species_extracted_with_ollama.csv")
# Define a function to extract goals from the project description
def extract_goals(project_goals):
    prompt = (
        "Extract the goals from this project description. "
        "Respond ONLY as a Python list of strings, e.g., ['Goal 1', 'Goal 2'], no extra text. "
        "For each goal, conclude to make it precise and short."
        f"Description: '{project_goals}'"
    )
    
    response = ollama.chat(
        model=model_name,
        messages=[{'role': 'user', 'content': prompt}]
    )
    
    raw_text = response['message']['content'].strip()
    print("RAW RESPONSE:", raw_text)  # For debugging
    
    try:
        result = ast.literal_eval(raw_text)
    except Exception as e:
        print(f"Parsing error: {e}")
        result = []
    
    return result

# Apply the function to the 'Project Goals' column
df_2['Goals from Ollama'] = df_2['Project Goals'].apply(extract_goals)
# Save the updated DataFrame to a new CSV file
df_2.to_csv("usda_species_extracted_with_ollama_and_goals.csv", index=False)

# %%
# Next we will extract main goals/ percentage from the project goals
import pandas as pd
# Load the existing CSV file
df_3 = pd.read_csv("usda_species_extracted_with_ollama_and_goals.csv")
# Define a function to extract goals from the project description
def extract_goals_2(project_goals):
    prompt = (
        "Extract the goals from this project description.\n "
        "After seeing the goals, conclude and classify them into main goals and their percentage.\n "
        "Respond ONLY as a Python dictionary, e.g., {Goal 1: 50%, Goal 2: 30%}, no extra text.\n "
        "The value should be a percentage calculated by (The total number of project goals associated with a certain classification) divided by the total project goals (The total length of the list)).\n "
        "The classifications are Environmental, Social, Economics, Urban Planning.\n "
        "With the logic given above, the total value of each list should add up to 100%. \n"
        "I want it to be in a precise pattern of {Environmental: 50%, Social: 30%, Economics: 10%, Urban Planning: 10%}, but these are just examples, you can change the values based on a principle I have given above. \n"
        "No explanation, no code, no extra text.\n "
        "No '' or any special characters in the response.\n "
        f"Description: '{project_goals}'"
    )
    
    response = ollama.chat(
        model=model_name,
        messages=[{'role': 'user', 'content': prompt}]
    )
    
    raw_text = response['message']['content'].strip()
    print("RAW RESPONSE:", raw_text)  # For debugging
    
    try:
        result = ast.literal_eval(raw_text)
    except Exception as e:
        print(f"Parsing error: {e}")
        result = []
    
    return result

# Apply the function to the 'Project Goals' column
df_3['Main Goals'] = df_3['Goals from Ollama'].apply(extract_goals_2)
# Save the updated DataFrame to a new CSV file
df_3.to_csv("usda_species_extracted_with_ollama_and_goals_2.csv", index=False)
# Out:
# RAW RESPONSE: {Environmental: 50%, Social: 40%, Economics: 10%, Urban Planning: 0%}
# Parsing error: invalid syntax (<unknown>, line 1)
# RAW RESPONSE: {Environmental: 50%, Social: 30%, Economics: 10%, Urban Planning: 10%}
#
# Here are the goals classified into their respective categories:
#
# - Enhance the beauty and welcoming atmosphere of campuses (Environmental)
# - Create an environment that is calming and awe-inspiring (Environmental)
# - Promote a deeper encounter with the divine (Social)
# - Increase number of trees in communities (Environmental)
# - Advocate for and educate about environmental justice (Environmental)
# - Support workforce development through hiring for tree care (Economics)
# - Provide peace and inner calm for visitors amidst gun violence (Social)
# - Enhance gardens and outdoor sitting areas (Urban Planning)
# Parsing error: invalid syntax (<unknown>, line 1)
# RAW RESPONSE: {Environmental: 60%, Social: 30%, Economics: 10%, Urban Planning: 0%}
# Parsing error: invalid syntax (<unknown>, line 1)
# RAW RESPONSE: {Environmental: 70%, Social: 20%, Economics: 10%, Urban Planning: 0%}
# Parsing error: invalid syntax (<unknown>, line 1)
# RAW RESPONSE: {Environmental: 50%, Social: 60%, Economics: 10%, Urban Planning: 0%}
# Parsing error: invalid syntax (<unknown>, line 1)
# RAW RESPONSE: {'Environmental': 50, 'Social': 30, 'Economics': 10, 'Urban Planning': 10}
# RAW RESPONSE: {Environmental: 9, Social: 3, Economics: 2, Urban Planning: 1}
# Parsing error: ':' expected after dictionary key (<unknown>, line 1)
# RAW RESPONSE: {Environmental: 50%, Social: 40%, Urban Planning: 10%}
#
# The goals associated with Environmental are: 'Restore wildlife habitat', 'Restore a specific clear-cut area with trees', 'Preserve BIPOC history and heritage', 'Resurrect the community garden'.
# The goals associated with Social are: 'Promote community unity', 'Cultivate intergenerational learning', 'Promote relations among diverse people', 'Create a safe space for LGBTQ+ individuals'.
# The goal associated with Urban Planning is: 'Develop edible spaces'
# Parsing error: invalid syntax (<unknown>, line 1)
# RAW RESPONSE: {Environmental: 75%, Social: 12.5%, Economics: 6.25%, Urban Planning: 6.25%}
# Parsing error: invalid syntax (<unknown>, line 1)
# RAW RESPONSE: {Environmental: 20%, Social: 60%, Economics: 10%, Urban Planning: 0%}
# Parsing error: invalid syntax (<unknown>, line 1)
# RAW RESPONSE: {Environmental: 75%, Social: 20%, Economics: 5%, Urban Planning: 0%}
# Parsing error: invalid syntax (<unknown>, line 1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 37
#      34     return result
#      36 # Apply the function to the 'Project Goals' column
# ---> 37 df_3['Main Goals'] = df_3['Goals from Ollama'].apply(extract_goals_2)
#      38 # Save the updated DataFrame to a new CSV file
#      39 df_3.to_csv("usda_species_extracted_with_ollama_and_goals_2.csv", index=False)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[26], line 20, in extract_goals_2(project_goals)
#       6 def extract_goals_2(project_goals):
#       7     prompt = (
#       8         "Extract the goals from this project description.\n "
#       9         "After seeing the goals, conclude and classify them into main goals and their percentage.\n "
#    (...)
#      17         f"Description: '{project_goals}'"
#      18     )
# ---> 20     response = ollama.chat(
#      21         model=model_name,
#      22         messages=[{'role': 'user', 'content': prompt}]
#      23     )
#      25     raw_text = response['message']['content'].strip()
#      26     print("RAW RESPONSE:", raw_text)  # For debugging
#
# File /opt/anaconda3/lib/python3.11/site-packages/ollama/_client.py:342, in Client.chat(self, model, messages, tools, stream, think, format, options, keep_alive)
#     297 def chat(
#     298   self,
#     299   model: str = '',
#    (...)
#     307   keep_alive: Optional[Union[float, str]] = None,
#     308 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     309   """
#     310   Create a chat response using the requested model.
#     311
#    (...)
#     340   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     341   """
# --> 342   return self._request(
#     343     ChatResponse,
#     344     'POST',
#     345     '/api/chat',
#     346     json=ChatRequest(
#     347       model=model,
#     348       messages=list(_copy_messages(messages)),
#     349       tools=list(_copy_tools(tools)),
#     350       stream=stream,
#     351       think=think,
#     352       format=format,
#     353       options=options,
#     354       keep_alive=keep_alive,
#     355     ).model_dump(exclude_none=True),
#     356     stream=stream,
#     357   )
#
# File /opt/anaconda3/lib/python3.11/site-packages/ollama/_client.py:180, in Client._request(self, cls, stream, *args, **kwargs)
#     176         yield cls(**part)
#     178   return inner()
# --> 180 return cls(**self._request_raw(*args, **kwargs).json())
#
# File /opt/anaconda3/lib/python3.11/site-packages/ollama/_client.py:120, in Client._request_raw(self, *args, **kwargs)
#     118 def _request_raw(self, *args, **kwargs):
#     119   try:
# --> 120     r = self._client.request(*args, **kwargs)
#     121     r.raise_for_status()
#     122     return r
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_client.py:827, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     812     warnings.warn(message, DeprecationWarning)
#     814 request = self.build_request(
#     815     method=method,
#     816     url=url,
#    (...)
#     825     extensions=extensions,
#     826 )
# --> 827 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     266     with ShieldCancellation():
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#     270     break
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     248         raise exc
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#     260     with self._pool_lock:
#     261         # Maintain our position in the request queue, but reset the
#     262         # status so that the request becomes queued again.
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     elif not self._connection.is_available():
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     131     with Trace("response_closed", logger, request) as trace:
#     132         self._response_closed()
# --> 133 raise exc
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:111, in HTTP11Connection.handle_request(self, request)
#     101     pass
#     103 with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#     119 return Response(
#     120     status=status,
#     121     headers=headers,
#    (...)
#     127     },
#     128 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:176, in HTTP11Connection._receive_response_headers(self, request)
#     173 timeout = timeouts.get("read", None)
#     175 while True:
# --> 176     event = self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#     178         break
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     209     event = self._h11_state.next_event()
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#     224     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /opt/anaconda3/lib/python3.11/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %%
# Clean data, clearing all things that are not spaces, commas, numbers, colon or letters
import pandas as pd
import re
# Load the existing CSV file
df_4 = pd.read_csv("usda_species_extracted_with_ollama_and_goals_2.csv")
# Remove all things that are not spaces, commas, colon, number or letters
def clean_text(text):
    if pd.isna(text):
        return ""
    # Keep only letters, numbers, spaces, commas, and colons
    return re.sub(r'[^a-zA-Z0-9\s,:\']', '', text)
# Apply the cleaning function to the 'Main Goals' column
df_4['Main Goals'] = df_4['Main Goals'].apply(clean_text)

# %%
# Save the updated DataFrame to a new CSV file
df_4.to_csv("usda_species_extracted_with_ollama_and_goals_3.csv", index=False)

# %%
df_4
# Out:
#                                     Organization Name  # Trees To Be Planted  \
# 0                           Vernon Park Church of God                   20.0
# 1                          St. Moses the Black Parish                   20.0
# 2                                 Wood St. Collective                   35.0
# 3                                     Groundwork Indy                   50.0
# 4                   Masjid Al-Qur'an Foundation, Inc.                   50.0
# 5                  Shelby County Economic Development                   20.0
# 6                               Cross Lutheran Church                   15.0
# 7                                    Echo Valley Hope                   20.0
# 8                         St. Michael Catholic Church                   15.0
# 9                          St. Titus One M. B. Church                   10.0
# 10                              Mr. Dads Fathers Club                  145.0
# 11                Faith Coalition for the Common Good                   40.0
# 12                 Arthur Lockhart Resource Institute                   15.0
# 13                      Solomon Community Temple, UMC                   16.0
# 14                Mother's Against Senseless Killings                   20.0
# 15                                  Rainbow Beach PAC                   15.0
# 16                 United Congregations of Metro East                   20.0
# 17      Lions Mathematics & Science Christian Academy                    8.0
# 18      Pilgrim's Progress Community Development Corp                   20.0
# 19                          Community Canopy Alliance                  100.0
# 20                           Evolution Sports Academy                    7.0
# 21                            Whatsoever You Do, Inc.                   10.0
# 22                        Greater Wabash Food Council                   50.0
# 23                                       Sheathed Inc                   16.0
# 24                     Pentecostal Church of Holiness                    6.0
# 25  Northern Illinois Conference of the United Met...                   20.0
# 26          Sixteenth Street Community Health Centers                   20.0
# 27                       Landmark Columbus Foundation                   30.0
# 28                                  Gary Food Council                    5.0
# 29      Wesley United Methodist Church, Charleston IL                   12.0
# 30                       Jacksonville Park Foundation                  200.0
# 31              Metcalfe Park Community Bridges, Inc.                    8.0
# 32                  Center for Interfaith Cooperation                   20.0
# 33          Indianapolis Muslim Community Association                   20.0
# 34             Anabaptist Mennonite Biblical Seminary                   20.0
# 35                         Englewood Christian Church                   50.0
# 36                               Cristo Rey St.Martin                   16.0
# 37               It Takes A Village Family of Schools                    8.0
# 38                               Urban Ecology Center                   10.0
# 39   Northwest Side Community Development Corporation                   20.0
# 40                            One Life Ministries Inc                   20.0
# 41  Fuller Park Community Dev    DBA   Eden Place ...                   20.0
# 42        Chicago Avenue Community Network Foundation                   20.0
# 43                             Renew Christian Church                   30.0
# 44                   Girl Scouts of Southern Illinois                   18.0
# 45              Housing Authority of Champaign County                   35.0
# 46                            Trinity Lutheran Church                    2.0
# 47                                  St Luke MB Church                   15.0
# 48                             Casa Esperanza Project                   10.0
# 49          Unitarian Universalist Church of Stockton                   10.0
# 50       Grace Congregational United Church of Christ                   20.0
# 51                        Stone Temple Baptist Church                   20.0
# 52                                           4 Osprey                   20.0
# 53                                         Just Roots                   15.0
# 54                           Youth Conservation Corps                   20.0
# 55                        Reformation Lutheran Church                   15.0
# 56                             Breaking the Cycle EBU                   20.0
# 57                                   ELS NO LIMIT NFP                   20.0
# 58                                                NaN                    NaN
# 59                                                NaN                    NaN
#
#                                   Project Description  \
# 0   We plan to use the urban and community forestr...
# 1   Our urban and community forestry project is ba...
# 2   Wood St. Collective owns and operates a half-a...
# 3   The “Indy Planted” project is a community-cent...
# 4   The community forestry project will have at it...
# 5   This grant will plant twenty, non-invasive, tr...
# 6    All trees that were selected are native and n...
# 7   All trees have been chosen from the list provi...
# 8   Our project entails planting 15 locally grown,...
# 9   Our urban and community forestry project consi...
# 10  Our Urban and Community Forestry Project aims ...
# 11  The project will include planting 40 trees of ...
# 12  The project will involve planting 15 native tr...
# 13  Our tree selection includes \n1 Chinkapin Oak,...
# 14  As advocates of Gun Violence, we will reach ou...
# 15  The Green Roots Initiative is an urban and com...
# 16  The tree planting project we would focus on is...
# 17  This initiative aims to beautify our campus an...
# 18  The PBC Green Team’s urban and community fores...
# 19  This project will include both tree planting a...
# 20  Our urban and forestry project is intended to ...
# 21  Atkinson House, now known as the Whatsoever Yo...
# 22  Greater Wabash Food Council (GWFC), a 501(c)(3...
# 23  This urban food forest project will include pl...
# 24  The PCH Veterans Memorial Peace Garden Fruit a...
# 25  In order to address environmental injustice in...
# 26  With the support of the Tree Canopy & Workforc...
# 27  This project involves planting 30 native trees...
# 28  This project will create a biodiverse communit...
# 29  We propose to plant 12 native trees in and nea...
# 30  We are living in an age of climate crisis, fac...
# 31  In January 2022, a mother was murdered by her ...
# 32  We propose to plant 20 Indiana native trees at...
# 33  The IMCA Eco-Canopy Project is a green initiat...
# 34  We will plant eight white oak (Quercus alba) t...
# 35  The proposed Englewood Urban Orchard is locate...
# 36  CRSM would like to plant a combination of site...
# 37  Our project will plant eight trees in the curr...
# 38  Support will go towards the land stewardship w...
# 39  Our microforest project includes planting and ...
# 40  The Sacred Forest project will provide shade, ...
# 41  The Urban Food Forest at Eden Place Farms aims...
# 42  CACNF will 20 tress, 10 fruit trees (5 apple t...
# 43  Through the Tree Canopy Project, Love Lamasco ...
# 44  The Girl Scouts of Southern Illinois (GSofSI) ...
# 45  The goal of the project is to improve environm...
# 46  We will be planting two trees: one Northern Re...
# 47  St. Luke's Green Team, in partnership with loc...
# 48  Casa Esperanza Project's Urban and Community F...
# 49  Our urban and community forestry project entai...
# 50  The project addresses the significant loss of ...
# 51  the Stone Temple Tree Ambassador Project aims ...
# 52  8 swamp white oak\n6 bur oaks\n2 pecans\n2 bal...
# 53  The project will be led by Just Roots and Grac...
# 54  Youth Conservation Corps (YCC) is implementing...
# 55  Reformation Lutheran Church will plant up to 1...
# 56  Our Tree Canopy Community Grant project, calle...
# 57  TBD because Northern Red Oak (Quercus rubra) c...
# 58                                                NaN
# 59                                                NaN
#
#                                         Project Goals  \
# 0   The combination of urban forestry and communit...
# 1   Our church members, visitors, and neighbors wi...
# 2   Our organization is 100% Black- and Latinx-led...
# 3   The primary goal of the “Indy Planted” project...
# 4   The people who live closest to the physical pr...
# 5   The Shelbyville Glenwood Cemetery and Forest P...
# 6   Environmental stewardship and climate resilien...
# 7   We believe the entire community can benefit. W...
# 8   Our vision for this project is multi-faceted: ...
# 9   This is a major project that benefits the comm...
# 10  Our project aims to enhance urban tree canopie...
# 11  1) The project will benefit the community by p...
# 12  The My Healing Space initiative envisions crea...
# 13  All of Creation will benefit from this project...
# 14  Project GoalsThe Abel Project is driven by a v...
# 15  Vision for the Green Roots InitiativeThe Green...
# 16  There is great pleasure to be experienced when...
# 17  Our initiative seeks to beautify our campus an...
# 18  The PBC Green Team’s Labyrinth Healing Park an...
# 19  All residents of Northwest Landing will benefi...
# 20  The vision for this area has many long-term be...
# 21  The House of Hospitality serves as a launching...
# 22  Currently, there are no certified arborists or...
# 23  Individuals who struggle with addiction often ...
# 24  The Veterans Memorial Peace Garden and Tree Wa...
# 25  The United Methodist Church has 298 churches i...
# 26  The goals of this project are to increase comm...
# 27  The trees are a key component of the vision to...
# 28  The project will benefit student interns, resi...
# 29  The vision for our project is to create a medi...
# 30  The Orchards of Grace Initiative seeks to prov...
# 31  North Star Park will benefit all of Metcalfe P...
# 32  The Interfaith Peace Canopy plans to bring tre...
# 33  The IMCA “Eco-Canopy Project” aims to create a...
# 34  Our goals include:\n1. To increase tree canopy...
# 35  The Englewood Urban Orchard Project benefits n...
# 36  The project has several goals and benefits. Th...
# 37  Our project envisions a transformative annual ...
# 38  The Urban Ecology Center (UEC), a non-profit i...
# 39  Project Beneficiaries\nThe main beneficiaries ...
# 40  The Sacred Forest project is inspired by the g...
# 41  Goal # 1 Address Fresh Food Insecurity: Provid...
# 42  The goal for our project is to create a place ...
# 43  Vision for the Love Lamasco Tree Canopy Projec...
# 44  Our planet’s need for trees is more urgent tha...
# 45  The primary beneficiaries of the project are y...
# 46  Goal 1: Plant and provide ongoing care for one...
# 47  The proposed project is located at 7251-55 S C...
# 48  Casa Esperanza Project's Urban and Community F...
# 49  The vision for our project is to create a sere...
# 50  This project will increase urban canopy and re...
# 51  The vision for our project is to create outdoo...
# 52  The project’s vision is inspiring and broad. T...
# 53  Many communities in Cook County lack access to...
# 54  This project targets environmental injustices ...
# 55  The goals of our project are three-fold:Help t...
# 56  Our “Reclaimed and Rooted” project has a goal ...
# 57  The Tranquility Project's Vision is to create ...
# 58                                                NaN
# 59                                                NaN
#
#                      Project Location Street Project Location Street line 2  \
# 0                       1975 East Joe Orr Rd
# 1                          331 E 71st Street
# 2                       3312 S. Halsted St.
# 3                        975 Burdsal Parkway
# 4                      11723 W BROWN DEER RD
# 5                               1501 W. Main                        Suite B
# 6                        1821 N. 16th Street
# 7                        E14604 County Rd. F
# 8                             1445 N 25th St
# 9                           12257 S. Emerald
# 10                         32 E 69th Street
# 11                          2208 E Kansas St
# 12                        4941 W Chicago Ave
# 13        3295 N Dr Martin Luther King Jr Dr
# 14                           7500 S. Stewart
# 15                            3111 E 77th St
# 16                        13 Vieux Carre Dr.                         Ste. 2
# 17                     1011 Porter st\t \t\t                            NaN
# 18                         1002 Eliza Street                            NaN
# 19                         1002 Udell Street                            NaN
# 20                              1004 W 61st                             NaN
# 21                            1082 VELP AVE.                            NaN
# 22                      1152 Bob Martin Dr,                             NaN
# 23                             1410 High St.                            NaN
# 24                  1444 South Keeler Avenue                            NaN
# 25                          147 South Keeler                            NaN
# 26  1935 S. 16th Street ,1616 W. Forest Home                            NaN
# 27                        200 Jackson Street                            NaN
# 28                             2190 Broadway                            NaN
# 29                        2206 Fourth Street
# 30                     225 South Clay Avenue                            NaN
# 31                        2652 N. 36 Street                             NaN
# 32                            2716 W 20th St                            NaN
# 33                       2846 Cold Spring Rd
# 34                          3003 Benham Ave.
# 35                  3029 E Washington Street                            NaN
# 36                       3106 Belvidere Road
# 37                     4020 W. Division St.                             NaN
# 38                        4023 W. Galena St.                            NaN
# 39                           4101 N. 31st St                            NaN
# 40                        4601 N Emerson Ave
# 41                       4911 S Shields Ave                             NaN
# 42                     501-509 North Harding                            NaN
# 43                     511 N Eleventh Avenue                            NaN
# 44                       600 St. Robert Dr.                             NaN
# 45                         608 E. University                            NaN
# 46                           660 E Walnut St                            NaN
# 47                       7251-55 S Coles Ave                            NaN
# 48                     8801 S Saginaw Avenue
# 49         Adams Ave, Tutty  and Taylor Park                            NaN
# 50                                 Adams St.                            NaN
# 51                                     Drake                            NaN
# 52           Garden Hills Elementary School                             NaN
# 53                              PO Box 16444
# 54                  Robert McClory Bike Path                            NaN
# 55         Washington Park: 4023 W Galena St                            NaN
# 56                         West Cedar Street                            NaN
# 57                      Woodcreek and Timber                            NaN
# 58                                       NaN                            NaN
# 59                                       NaN                            NaN
#
#     Project Location City Project Location State Project Location Zip  \
# 0                 Lynwood                     IL                60411
# 1                 Chicago                     IL                60619
# 2                 Chicago                     IL                60608
# 3            Indianapolis                     IN                46208
# 4               MILWAUKEE                     WI           53224-1446
# 5             Shelbyville                     IL                62565
# 6               Milwaukee                     WI                53205
# 7                 Ontario                     WI                54651
# 8               Milwaukee                     WI                53205
# 9      Chicago, IL  60628                     IL                60628
# 10               Chicago                      IL                60637
# 11            Springfield                     IL                62703
# 12                Chicago                     IL                60651
# 13              Milwaukee                     WI                53212
# 14                Chicago                     IL                60620
# 15                Chicago                     IL                60649
# 16         East St. Louis                     IL                62203
# 17               Waukegan                    IL                 60085
# 18             Fort Wayne                Indiana                46803
# 19           Indianapolis                Indiana                46208
# 20                Chicago               Illinois                60621
# 21              GREEN BAY                     WI                54303
# 22                  Carmi               Illinois                62821
# 23             Fort Wayne                Indiana                46808
# 24                Chicago                     IL                60623
# 25      Chicago Illinois                Illinois                60624
# 26              Milwaukee              Wisconsin                53204
# 27               Columbus                Indiana                47201
# 28                   Gary                Indiana                46407
# 29             Charleston                     IL                61920
# 30           Jacksonville               Illinois                62650
# 31              Milwaukee              Wisconsin                53210
# 32           Indianapolis                Indiana                46222
# 33           Indianapolis                     IN                46222
# 34                Elkhart                     IN                46517
# 35           Indianapolis                Indiana                46201
# 36               Waukegan                     IL                60085
# 37                Chicago               Illinois                60651
# 38              Milwaukee              Wisconsin                53208
# 39              Milwaukee              Wisconsin                53216
# 40           Indianapolis                     IN                46226
# 41                Chicago               Illinois                60609
# 42                Chicago               Illinois                60624
# 43  Evansville, IN, 47720                Indiana                47720
# 44                Cahokia               Illinois                62206
# 45              Champaign               Illinois                61822
# 46                 Canton               Illinois                61520
# 47                Chicago               Illinois                60649
# 48                Chicago                     IL                60617
# 49               Freeport               Illinois                61032
# 50             TWO RIVERS              Wisconsin                54241
# 51                Chicago               Illinois                60623
# 52              Champaign               Illinois                61821
# 53                Chicago                     IL                60616
# 54           Waukegan, IL               Illinois                60087
# 55              Milwaukee              Wisconsin                53208
# 56                Olmsted               Illinois                62970
# 57            Bolingbrook               Illinois                60490
# 58                    NaN                    NaN                  NaN
# 59                    NaN                    NaN                  NaN
#
#                    Organization Address 1  \
# 0                    1975 East Joe Orr Rd
# 1                       331 E 71st Street
# 2                    3312 S. Halsted St.
# 3                     975 Burdsal Parkway
# 4                   11723 W BROWN DEER RD
# 5                            1501 W. Main
# 6                     1821 N. 16th Street
# 7                     E14604 County Rd. F
# 8                          1445 N 25th St
# 9                        12257 S. Emerald
# 10                      32 E 69th Street
# 11                       2208 E Kansas St
# 12                     4941 W Chicago Ave
# 13     3295 N Dr Martin Luther King Jr Dr
# 14                        7500 S. Stewart
# 15                         3111 E 77th St
# 16                     13 Vieux Carre Dr.
# 17                         1011 Porter st
# 18                        1331 Gay Street
# 19                       431 Rainbow Lane
# 20                         3741 W. 86h St
# 21                         1082 VELP AVE.
# 22                             PO Box 217
# 23                        1202 Wooster Rd
# 24               1444 South Keeler Avenue
# 25                       303 E Wacker Dr
# 26              1032 S Cesar Chavez Drive
# 27                         408 6th Street
# 28                   2382 west 19th place
# 29                     2206 Fourth Street
# 30                  225 South Clay Avenue
# 31                   3624 W. North Avenue
# 32                1100 W 42nd St, Ste 125
# 33                    2846 Cold Spring Rd
# 34                       3003 Benham Ave.
# 35                        57 N. Rural St
# 36                    3106 Belvidere Road
# 37                      2240 W. Ogden Ave
# 38                         1500 E Park Pl
# 39         4201 N. 27th Street, 7th Floor
# 40                     4601 N Emerson Ave
# 41                4417 South Stewart Ave.
# 42               3705 West Chicago Avenue
# 43                       2240 Bismark Ave
# 44                   4 Ginger Creek Pkwy.
# 45                     2008 N. Market St.
# 46                      301 E Chestnut St
# 47                       7262 S Coles Ave
# 48                  8801 S Saginaw Avenue
# 49                         219 N Pearl St
# 50                      2801 Garfield St.
# 51                3622 West Douglas Blvd.
# 52              114County Road 1900 North
# 53                           PO Box 16444
# 54               1020 W. Greenwood Avenue
# 55                     3806 W. Lisbon Ave
# 56                  204 S. Blanche Street
# 57  609 Sherwood CT, Romeoville, IL 60446
# 58                                    NaN
# 59         Show the Debugger Trace Report
#
#                    Organization Address 2   Organization City  \
# 0                                                     Lynwood
# 1                                                     Chicago
# 2                                                     Chicago
# 3                                                Indianapolis
# 4                                                   MILWAUKEE
# 5                                 Suite B         Shelbyville
# 6                                                   Milwaukee
# 7                                                     Ontario
# 8                                                   Milwaukee
# 9                                          Chicago, IL  60628
# 10                                                   Chicago
# 11                                                Springfield
# 12                                                    Chicago
# 13                                                  Milwaukee
# 14                                                    Chicago
# 15                                                    Chicago
# 16                                 Ste. 2      East St. Louis
# 17                                                   waukegan
# 18                                                 Fort Wayne
# 19                                               Indianapolis
# 20                                                    Chicago
# 21                                                  GREEN BAY
# 22                                                 Bridgeport
# 23                                     66         Winona Lake
# 24                                                    Chicago
# 25                             Suite 2020             Chicago
# 26                                                  Milwaukee
# 27                                                   Columbus
# 28                                                       Gary
# 29                                                 Charleston
# 30                                               Jacksonville
# 31                             2nd Floor           Milwaukee
# 32                                               Indianapolis
# 33                                               Indianapolis
# 34                                                    Elkhart
# 35                                               Indianapolis
# 36                                                   Waukegan
# 37                                2nd Fl.             Chicago
# 38                                                  Milwaukee
# 39                                                  Milwaukee
# 40                                               Indianapolis
# 41                                                    Chicago
# 42                                                    Chicago
# 43                                                 Evansville
# 44                                                Glen Carbon
# 45                                                  Champaign
# 46                                                     Canton
# 47                                 Office             Chicago
# 48                                                    Chicago
# 49                                                   Stockton
# 50                                                 TWO RIVERS
# 51                                                    Chicago
# 52                                                    Seymour
# 53                                                    Chicago
# 54                                                   Waukegan
# 55                                                  Milwaukee
# 56                                                     Mounds
# 57  609 Sherwood CT, Romeoville, IL 60446          Romeoville
# 58                                    NaN                 NaN
# 59                                    NaN                 NaN
#
#    Organization State Organization Postal Code  \
# 0                  IL                    60411
# 1                  IL                    60619
# 2                  IL                    60608
# 3                  IN                    46208
# 4                  WI               53224-1446
# 5                  IL                    62565
# 6                  WI                    53205
# 7                  WI                    54651
# 8                  WI                    53205
# 9                  IL                    60628
# 10                 IL                    60637
# 11                 IL                    62703
# 12                 IL                    60651
# 13                 WI                    53212
# 14                 IL                    60620
# 15                 IL                    60649
# 16                 IL                    62203
# 17                 IL                    60085
# 18                 IN                    46803
# 19                 IN                    46260
# 20                 IL                    60652
# 21                 WI                    54303
# 22                 IL                    62417
# 23                 IN                    46590
# 24                 IL                    60623
# 25                 IL                    60601
# 26                 WI                    53204
# 27                 IN                    47201
# 28                 IN                    46404
# 29                 IL                    61920
# 30                 IL                    62650
# 31                 WI                    53208
# 32                 IN                    46208
# 33                 IN                    46222
# 34                 IN                    46517
# 35                 IN                    46201
# 36                 IL                    60085
# 37                 IL                    60612
# 38                 WI                    53211
# 39                 WI                    53216
# 40                 IN                    46226
# 41                 IL                    60609
# 42                 IL                    60651
# 43                 IN                    47720
# 44                 IL                    62034
# 45                 IL                    61822
# 46                 IL                    61520
# 47                 IL                    60649
# 48                 IL                    60617
# 49                 IL                    61085
# 50                 WI                    54241
# 51                 IL                    60623
# 52                 IL                    61875
# 53                 IL                    60616
# 54                 IL                    60087
# 55                 WI                    53208
# 56                 IL                    62964
# 57                 IL                    60446
# 58                NaN                      NaN
# 59                NaN                      NaN
#
#                                 Workforce Development  \
# 0   Our project will support urban and community f...
# 1
# 2   In our experience, people without strong ties ...
# 3   The “Indy Planted” project aligns closely with...
# 4
# 5   The City of Shelbyville employs 31 full time e...
# 6
# 7   We will be giving students from the NOW school...
# 8   "Planting Trees, Growing Community" supports u...
# 9   We plan to hire young adults who were previous...
# 10  The project will feature hands-on workshops th...
# 11  This project support urban and community fores...
# 12  The My Healing Space project actively integrat...
# 13  Our strategy is to start young and excite inte...
# 14  The Abel Project directly contributes to urban...
# 15
# 16
# 17                                                NaN
# 18  This project provides a unique opportunity to ...
# 19  Since maintenance of existing mature trees has...
# 20  The goal is to provide some level of economic ...
# 21  Our volunteer groundskeeper, a graduate of an ...
# 22  The White County project supports urban and co...
# 23  Our goal is to establish a healing orchard and...
# 24  Currently, the Veterans Memorial Peace Garden ...
# 25  One of the many goals of HEAL Well is to work ...
# 26                                                NaN
# 27  There has been recent momentum in the City of ...
# 28  Our project supports urban and community fores...
# 29  Our project supports urban and community fores...
# 30  Fifty percent of the funding from this proposa...
# 31  As previously described, the Metcalfe Park Gre...
# 32  The Interfaith Peace Canopy project will suppo...
# 33  1. Volunteer Engagement and Leadership\nThe Kh...
# 34  The workshops that arborist Steve Thomas will ...
# 35  The Englewood Urban Orchard Project supports u...
# 36                                                NaN
# 37  While the Village Roots project does not have ...
# 38  The Urban Ecology Center's Green Career Pathwa...
# 39  Our microforest project at Green Tech Station ...
# 40  The Sacred Forest project supports urban and c...
# 41  This project will serve as a training planform...
# 42  CACNF Green Touch Project will train and engag...
# 43  The Love Lamasco Tree Canopy Project not only ...
# 44  Before planting the trees, we plan to take Gir...
# 45  This project plays a pivotal role in supportin...
# 46  The workforce development component of our pro...
# 47  Our project at St. Luke's MB Church is deeply ...
# 48  Casa Esperanza Project plans to support urban ...
# 49  Our project supports urban and community fores...
# 50  This project directly supports urban and commu...
# 51  The Tree Ambassador Program will support urban...
# 52  Creating a workforce development component for...
# 53  This project will support workforce developmen...
# 54  Through this project, YCC will establish clear...
# 55  The Neighborhood Tree Planting and Maintenance...
# 56  Our project supports urban and community fores...
# 57  For the hiring of the youth, the Tranquility p...
# 58                                                NaN
# 59                                                NaN
#
#                         Planting and Maintenance Plan  \
# 0   We will utilize the services of a local landsc...
# 1   Our parish contracts with a landscape company ...
# 2   Wood St. Collective staff has forestry certifi...
# 3   Our planting and maintenance plan for the “Ind...
# 4   The planting strategy is twofold. We have to p...
# 5   Eloe Landscapes, Garden, and Home, LLC owner, ...
# 6   Tree Maintenance Plan (3-Year)\nYear 1: Establ...
# 7   Our location has no buildings or any wiring. T...
# 8   To ensure the long-term survival and health of...
# 9   Planting Plan\n\nTo ensure that our trees surv...
# 10  Planting will be scheduled in optimal seasons ...
# 11  1) Have the students trained in tree planting/...
# 12  To ensure the successful establishment, growth...
# 13  Depending on the weather, Johnson's Nursery wi...
# 14  Tree Planting and Maintenance Plan\nThe succes...
# 15  Planting and Maintenance Plan for the Green Ro...
# 16  Tree Planting Plan\nDetermine list of trees to...
# 17  Maintenance and Sustainability\nEstablish a Ma...
# 18  Planting and Maintenance Plan\n\nOur tree plan...
# 19  Planting Plan - Trees will be planted with ove...
# 20  Year 1: Planting Phase\nWatering to ensure tre...
# 21  Based on the plans from Green Bay Landscape an...
# 22  In addtion tothe US Forest Service's Manual, w...
# 23  Our goal to create a healing orchard, communit...
# 24  Detailed Planting and Maintenance Plan (3 Year...
# 25  We plan to plant the trees at the end of April...
# 26  For the planting and maintenance of the trees,...
# 27  The team will carry out the goals of the proje...
# 28  To ensure the long-term survival and health of...
# 29  • 2025\no Planting: In spring, 2025, trees wil...
# 30  • Plans for planting and mulching of the trees...
# 31  MPCB will implement a comprehensive maintenanc...
# 32  The planting and tree maintenance plan is in i...
# 33  Planting and Maintenance Plan for IMCA Eco-Can...
# 34  To ensure the long-term survival and health of...
# 35  YEAR 1: ESTABLISHMENT OF ORCHARD (Fall 2024 – ...
# 36  The tree planting would be done by student and...
# 37  The Village Roots tree planting initiative is ...
# 38  The Urban Ecology Center is meeting the need f...
# 39  Planting & Mulching Plan\nHoppe Tree Service w...
# 40  Planting Plan:\nTo ensure the long-term surviv...
# 41  Spring (March - May)\n1. Pruning (Late March -...
# 42  To ensure the long-term survival and health of...
# 43  By implementing this detailed planting and mai...
# 44  Ensuring the survival and long-term health of ...
# 45  Before any trees are planted, the site will un...
# 46  The trees will be planted and maintained by th...
# 47  We will implement a comprehensive 3-year plan ...
# 48  Casa Esperanza Project is committed to succeed...
# 49  To ensure the long-term survival and health of...
# 50  The City of Two Rivers will take on responsibi...
# 51  Planting Plan:\nTo ensure the long-term surviv...
# 52  YEAR ONE\n\nPlanting and Maintenance Plan (mem...
# 53  All 20 trees will be planted on the south end ...
# 54  Planting Plan\nThe tree planting will occur ov...
# 55  To ensure the long-term survival and health of...
# 56  To ensure the long-term survival and health of...
# 57  All hands-on deck.\nEach resource will be avai...
# 58                                                NaN
# 59                                                NaN
#
#                                  USDA Matched Species  \
# 0   ['Eastern White Pine', 'apple', 'Pine', 'Red M...
# 1                                            ['pear']
# 2         ['apple', 'pear', 'pecan', 'plum', 'peach']
# 3                                           ['apple']
# 4   ['Bald Cypress', 'Tulip', 'oak', 'Northern Red...
# 5                      ['Coffee', 'Catalpa', 'Tulip']
# 6   ['Plum', 'Sugar Maple', 'Northern Red Oak', 'O...
# 7   ['Redbud', 'oak', 'catalpa', 'pine', 'Eastern ...
# 8                ['maple', 'apple', 'pear', 'ginkgo']
# 9                          ['Buckeye', 'Red Buckeye']
# 10  ['Serviceberry', 'Birch', 'Swamp White Oak', '...
# 11  ['Fringetree', 'Redbud', 'Chinquapin', 'Dogwoo...
# 12                         ['oak', 'maple', 'redbud']
# 13  ['Serviceberry', 'Shagbark Hickory', 'Redbud',...
# 14                                                 []
# 15        ['Northern Red Oak', 'Tulip', 'Gum', 'Oak']
# 16  ['Coffeetree', 'Sycamore', 'Northern Catalpa',...
# 17                                                 []
# 18                                  ['apple', 'pear']
# 19                                                 []
# 20                                                 []
# 21                                   ['cedar', 'Bay']
# 22                                          ['peach']
# 23                                  ['peach', 'pear']
# 24                ['peach', 'apple', 'pear', 'pecan']
# 25                             ['Shumard Oak', 'Oak']
# 26                                      ['threefold']
# 27  ['Tulip', 'Sycamore', 'Platanus occidentalis',...
# 28                                 ['peach', 'apple']
# 29  ['apple', 'oak', 'pear', 'peach', 'hornbeam', ...
# 30       ['Plum', 'Pear', 'Peach', 'Pawpaw', 'Apple']
# 31                                          ['peach']
# 32                                                 []
# 33                                                 []
# 34  ['apple', 'American hornbeam', 'Quercus alba',...
# 35                                                 []
# 36  ['eastern redbud', 'oak', 'Hackberry', 'redbud...
# 37  ['Sugar Maple', 'Redbud', 'Littleleaf Linden',...
# 38  ['oak', 'Quercus bicolor', 'Quercus imbricaria...
# 39  ['Cedar', 'Ostrya virginiana', 'Allegheny Serv...
# 40                             ['peach', 'Sunflower']
# 41               ['peach', 'apple', 'walnut', 'pear']
# 42           ['peach', 'tulip', 'apple', 'hackberry']
# 43  ['Redbud', 'Oak', 'Pecan', 'Bur Oak', 'Eastern...
# 44                                                 []
# 45  ['Swamp White Oak', 'Northern Red Oak', 'Pine'...
# 46        ['Northern Red Oak', 'Tulip', 'Oak', 'ash']
# 47  ['Plum', 'Carya Illinoinensis', 'Redbud', 'Nor...
# 48     ['Cedar', 'Thuja occidentalis', 'White Cedar']
# 49                                            ['Oak']
# 50                                                 []
# 51                                                 []
# 52  ['cypress', 'swamp white oak', 'oak', 'bald cy...
# 53  ['apple', 'Pyrus Communis', 'Redbud', 'pear', ...
# 54  ['Swamp White Oak', 'Pine', 'Butternut', 'Oak'...
# 55                                                 []
# 56  ['Plum', 'Bald Cypress', 'Swamp White Oak', 'R...
# 57  ['oak', 'Northern Red Oak', 'Quercus rubra', '...
# 58                                                 []
# 59                                                 []
#
#                                   Species from Ollama  \
# 0   {'Eastern White Pine': 2, 'Red Maple': 2, 'Eas...
# 1   {'northern_red_oak': 2, 'pagoda_dogwood': 2, '...
# 2   {'Apple': 6, 'Pear': 6, 'Cherry': 6, 'Peach': ...
# 3                            {'Honeycrisp apple': 50}
# 4                                                  {}
# 5   {'Catalpa': 2, 'Burr Oak': 3, 'Northern Red Oa...
# 6   {'Dwarf Alberta Spruce': 8, 'Honeycrisp Apple'...
# 7                                                  {}
# 8   {'Red Maple': 2, 'Maple': 4, 'Ornamental Pear'...
# 9                                 {'Red Buckeye': 10}
# 10  {'Apple (Malus domestica)': 30, 'Eastern Redbu...
# 11  {'Pagoda Dogwood': 5, 'Fringetree': 5, 'Easter...
# 12                {'Oak': 5, 'Maple': 5, 'Redbud': 5}
# 13  {'Chinkapin Oak': 1, 'Shagbark Hickory': 1, 'B...
# 14                                       {'Tree': 20}
# 15  {'Northern Red Oak': 5, 'Tulip Poplar': 4, 'Sw...
# 16  {'Northern Catalpa': 3, 'Hackberry': 3, 'Kentu...
# 17        {'Tree': 4, 'Memorial Tree (Red Maple)': 1}
# 18  {'Red Maple': 3, 'Serviceberry': 3, 'Eastern R...
# 19                                                 {}
# 20                {'Oak': 2, 'Maple': 2, 'Cherry': 1}
# 21                                                 {}
# 22                                 {'Peach tree': 25}
# 23  {'Red Apple': 6, 'Peach': 6, 'Pear': 26, 'Cher...
# 24    {'Apple': 1, 'Peach': 1, 'Pear': 1, 'Pecan': 1}
# 25                                {'Shumard Oak': 20}
# 26               {'Street Trees (not specified)': 20}
# 27  {'Celtis occidentalis-Hackberry': 6, 'Gymnocla...
# 28              {'Apple': 1, 'Peach': 2, 'Cherry': 2}
# 29  {'Dogwood': 2, 'Hornbeam': 1, 'Apple': 3, 'Pea...
# 30  {'Apple': 33.333333333333336, 'Pear': 33.33333...
# 31                                  {'Peach tree': 8}
# 32              {'Indiana Native (undetermined)': 20}
# 33                               {'Native trees': 10}
# 34  {'White Oak': 8, 'American Beech': 4, 'America...
# 35  {'Small fruit trees': None, 'Large fruit and n...
# 36  {'Hackberry': 1, 'serviceberry': 8, 'eastern r...
# 37  {'Honeylocust': 2, 'Littleleaf Linden': 2, 'Ea...
# 38  {'Quercus bicolor': None, 'Quercus imbricaria'...
# 39  {'Amelanchier laevis': 1, 'Carpinus carolinian...
# 40  {'Northern Pecan': 3, 'Sunflower PawPaw': 2, '...
# 41  {'Apple': 4, 'Peach': 2, 'Walnut': 2, 'Cherry'...
# 42  {'Apple': 5, 'Peach': 5, 'Tulip Tree': 5, 'Hac...
# 43  {'Eastern Redbud': 10, 'Bur Oak': 10, 'Pecan T...
# 44       {'Shade trees': 9, 'Fruit bearing trees': 9}
# 45  {'Northern Red Oak': None, 'Swamp White Oak': ...
# 46           {'Northern Red Oak': 1, 'Tulip Tree': 1}
# 47  {'Sand Cherry Tree': 2, 'American Plum': 3, 'S...
# 48                         {'Thuja occidentalis': 10}
# 49                                    {'Red Oak': 10}
# 50                               {'Native Trees': 20}
# 51  {'Pears': 4, 'Peaches': 4, 'Apples': 4, 'Plums...
# 52  {'Swamp White Oak': 8, 'Bur Oak': 6, 'Pecan': ...
# 53  {'Paw Paw (Asimina Triloba)': 5, 'Service Berr...
# 54  {'Bur Oak': 3, 'Swamp White Oak': 3, 'Chinkapi...
# 55                       {'Species': [], 'Count': 15}
# 56  {'Redbud': 7, 'American Plum': 2, 'Pagoda Dogw...
# 57                                                 {}
# 58                                         {'Oak': 2}
# 59                                        {'Oak': 10}
#
#                                     Goals from Ollama  \
# 0   ['Improve Air Quality', 'Enhance Aesthetic App...
# 1   ['Enhance the beauty and welcoming atmosphere ...
# 2   ['Improve climate resilience in low-income Chi...
# 3   ['Create a sustainable community orchard', 'In...
# 4   ['Benefit local residents', 'Benefit animals a...
# 5                                                  []
# 6   ['Environmental Stewardship', 'Climate Resilie...
# 7   ['Promote community unity', 'Restore wildlife ...
# 8   ['Provide shade to combat heat islands', 'Redu...
# 9   ['Create a peaceful and beautiful community sp...
# 10  ['Enhance urban tree canopies', 'Foster workfo...
# 11  ['Promote health in the community', 'Address a...
# 12  ['Create an urban oasis fostering environmenta...
# 13  ['Stewardship', 'Create a peaceful community s...
# 14  ['Emotional Healing for Families of Victims', ...
# 15                                                 []
# 16                                                 []
# 17                                                 []
# 18  ['Create an accessible, green space addressing...
# 19  ['Train area residents in tree care and manage...
# 20  ['Empower residents', 'Provide urban oasis', '...
# 21  ['Improve exterior aesthetics of House of Hosp...
# 22  ['Provide training to the next generation of c...
# 23  ['Improve mental health through tree planting'...
# 24  ['Honor veterans', 'Provide a tranquil space f...
# 25  ['Develop collaborative partnerships with chur...
# 26                                                 []
# 27  ['Redesign Downtown Entrance Plaza for reflect...
# 28                                                 []
# 29  ['Curb food insecurity for students and commun...
# 30  ['Provide significant environmental benefits',...
# 31  ['Increase safe public green spaces', 'Decreas...
# 32  ['Goal 1: Create a community gathering space w...
# 33  ['Create environmentally enriching green space...
# 34  ['Increase tree canopy along Benham Avenue', '...
# 35  ['Fostering a skilled workforce', 'Enhancing t...
# 36  ['Create an attractive and inviting open space...
# 37  ['Enhance urban tree canopy coverage in Humbol...
# 38  ['Expand green job opportunities', 'Increase a...
# 39  ['Engage K-12 students in environmental educat...
# 40  ['Plant a sacred forest', 'Benefit immediate n...
# 41  ['Address Fresh Food Insecurity', 'Enhance Com...
# 42  ['Create a tranquil green space', 'Connect sen...
# 43  ['Beautification and Environmental Enhancement...
# 44  ['Plant 18 trees in nine schools', 'Provide ha...
# 45  ['Empower Youth', 'Improve Community Environme...
# 46  ['Plant and provide ongoing care for trees in ...
# 47  ['Revitalize vacant lots into a green sanctuar...
# 48  ['Healing and empowerment of survivors of abus...
# 49  ['Create serene green area enhancing community...
# 50  ['Increase urban canopy', 'Reduce stormwater r...
# 51  ['Improve Air Quality', 'Reduce Urban Heat', '...
# 52  ['Improve learning outcomes for students at Ge...
# 53  ['Expand existing orchard', 'Produce more food...
# 54  ['Improve air quality through increased tree c...
# 55  ['Restore urban tree canopy in Washington Park...
# 56  ['Plant 20 native trees in two locations', 'Re...
# 57  ['Create a peaceful oasis', 'Inspire positive ...
# 58  ['Develop an AI-powered chatbot for customer s...
# 59  ['Develop a machine learning model for predict...
#
#                                            Main Goals
# 0   'Environmental: 60', 'Social: 30', 'Economics:...
# 1   'Environmental: 60', 'Social: 30', 'Economics:...
# 2   'Environmental: 80', 'Social: 16', 'Economics:...
# 3   'Environmental: 70', 'Social: 20', 'Economics:...
# 4   'Environmental: 50', 'Social: 40', 'Economics:...
# 5
# 6   'Environmental: 80', 'Social: 20', 'Economics:...
# 7
# 8   'Environmental: 60', 'Social: 20', 'Economics:...
# 9   'Environmental: 60', 'Social: 30', 'Economics:...
# 10  'Environmental: 60', 'Social: 30', 'Economics:...
# 11  'Environmental: 50', 'Social: 30', 'Economics:...
# 12  'Environmental: 50', 'Social: 30', 'Economics:...
# 13  'Environmental: 60', 'Social: 20', 'Economics:...
# 14  'Environmental: 40', 'Social: 30', 'Economics:...
# 15
# 16  'Environmental:35', 'Social:40', 'Economics:15...
# 17  'Environmental: 75', 'Social: 12', 'Economics:...
# 18  'Environmental: 50', 'Social: 30', 'Economics:...
# 19          'Environmental: 80', 'Urban Planning: 20'
# 20  'Environmental: 70', 'Social: 20', 'Economics:...
# 21
# 22  'Environmental: 60', 'Social: 20, Economics: 1...
# 23  'Environmental: 50, Social: 40, Economics: 10,...
# 24  'Environmental: 80', 'Social: 15', 'Economics:...
# 25  'Environmental: 70', 'Social: 15', 'Economics:...
# 26
# 27  'Environmental: 30', 'Urban Planning: 30', 'So...
# 28  'Environmental:60', 'Social:20', 'Economics:10...
# 29  'Environmental: 60', 'Social: 30', 'Economics:...
# 30  'Environmental: 70', 'Social: 20', 'Economics:...
# 31
# 32  'Environmental: 30, Social: 40, Economics: 20,...
# 33  'Environmental: 60', 'Social: 20', 'Economics:...
# 34              'Environmental: 6667', 'Social: 3333'
# 35  'Environmental: 50', 'Social: 30', 'Economics:...
# 36  'Environmental: 60', 'Social: 20', 'Urban Plan...
# 37  'Environmental: 70', 'Social: 20', 'Economics:...
# 38  'Environmental: 70', 'Social: 10', 'Economics:...
# 39  'Environmental: 65', 'Social: 30', 'Urban Plan...
# 40  'Environmental: 75', 'Social: 20', 'Economics:...
# 41  'Environmental: 70', 'Social: 20', 'Economics:...
# 42                  'Environmental: 80', 'Social: 20'
# 43  'Environmental: 100', 'Social: 0', 'Economics:...
# 44  'Environmental: 70', 'Social: 20', 'Economics:...
# 45                  'Environmental: 80', 'Social: 20'
# 46                  'Environmental: 50', 'Social: 50'
# 47  'Environmental: 50', 'Social: 30', 'Economics:...
# 48  'Environmental: 50, Social: 30, Economics: 20,...
# 49  'Environmental: 70', 'Social: 20', 'Urban Plan...
# 50
# 51  'Environmental: 60', 'Social: 20', 'Economics:...
# 52  'Environmental: 30', 'Social: 50', 'Economics:...
# 53
# 54  'Environmental: 80', 'Social: 10', 'Economics:...
# 55  'Environmental: 75', 'Social: 20', 'Economics:...
# 56                  'Environmental: 60', 'Social: 40'
# 57  'Environmental: 60', 'Social: 20', 'Economics:...
# 58
# 59  'Environmental: 0', 'Social: 0', 'Economics: 6...

# %%
import pandas as pd
import ast
import ollama  # Make sure you installed and running Ollama
model_name = "mistral"  # Or whatever your active model is

# Load data
df_5 = pd.read_csv("usda_species_extracted_with_ollama_and_goals_3.csv")

# Define function to extract estimated workforce
def extract_employment(trees_planted, workforce_development):
    
    if pd.isna(trees_planted) and pd.isna(workforce_development):
        return None
    prompt = (
        "Estimate the number of workers involved in the following tree planting project.\n"
        "Try to extract it directly from the Workforce Development description.\n"
        "If not available, try to estimate based on the number of trees planted.\n"
        "Return ONLY a number. If not possible, return None.\n\n"
        "Please, no explanation, just a NUMBER.\n"
        f"Number of trees to be planted: {trees_planted}\n"
        f"Workforce Development description: {workforce_development}"
    )
    
    try:
        response = ollama.chat(
            model=model_name,
            messages=[{'role': 'user', 'content': prompt}]
        )
        raw_text = response['message']['content'].strip()
        print("RAW RESPONSE:", raw_text)

        # Try parsing as int or float, else return None
        try:
            result = int(raw_text)
        except ValueError:
            try:
                result = float(raw_text)
            except ValueError:
                result = None

    except Exception as e:
        print(f"Ollama error: {e}")
        result = None

    return result

# Apply to dataframe (this might take time if many rows)
df_5["Estimated_Workforce"] = df_5.apply(
    lambda row: extract_employment(row.get("# Trees To Be Planted", ""), row.get("Workforce Development", "")),
    axis=1
)

# Save the updated file
df_5.to_csv("usda_species_with_estimated_workforce.csv", index=False)
# Out:
# RAW RESPONSE: 35
# RAW RESPONSE: None (not enough information)
# RAW RESPONSE: 21
# RAW RESPONSE: 30
# RAW RESPONSE: The Workforce Development description does not provide specific information on the number of workers involved in the project. Based on the number of trees (50), it's difficult to estimate the exact number of workers without additional context such as planting speed or tree-to-worker ratio. Therefore, I cannot return a number.
#
# If you would like, I can provide an explanation of how I might try to make this estimation based on available information.
# RAW RESPONSE: 56
# RAW RESPONSE: None (Insufficient information provided)
# RAW RESPONSE: 150
# RAW RESPONSE: None (No specific number of workers mentioned in the provided description)
# RAW RESPONSE: None (insufficient information provided to estimate the number of workers)
# RAW RESPONSE: None (Insufficient information provided to estimate the number of workers)
# RAW RESPONSE: None (since the number of workers is not provided in the Workforce Development description)
# RAW RESPONSE: 25
# RAW RESPONSE: 6 (excluding volunteers and companies)
# RAW RESPONSE: 250+ (estimated based on various training programs, youth engagement programs, local economic opportunities, and ongoing education)
# RAW RESPONSE: None (insufficient information)
# RAW RESPONSE: None (insufficient information)
# RAW RESPONSE: None
# RAW RESPONSE: 50
# RAW RESPONSE: 7
# RAW RESPONSE: None (as the number of workers isn't mentioned directly in the provided description)
# RAW RESPONSE: None
# RAW RESPONSE: None (No specific number mentioned for the White County project workforce)
# RAW RESPONSE: 40
# RAW RESPONSE: None (as no specific number is provided)
# RAW RESPONSE: None
# RAW RESPONSE: None
# RAW RESPONSE: None (No information provided about the number of workers required for the project)
# RAW RESPONSE: None (insufficient information to estimate number of workers)
# RAW RESPONSE: 15
# RAW RESPONSE: 10
# RAW RESPONSE: None
# RAW RESPONSE: 2 (Interfaith Enrichment Corps member + one person selected by the church)
# RAW RESPONSE: 50
# RAW RESPONSE: None
# RAW RESPONSE: 50
# RAW RESPONSE: None
# RAW RESPONSE: 300
# RAW RESPONSE: None (Direct description does not provide information about tree planting workforce)
# RAW RESPONSE: None
# RAW RESPONSE: None (as the number of workers is not explicitly mentioned in the description)
# RAW RESPONSE: None (Since the number of workers is not provided in the description)
# RAW RESPONSE: None (The Workforce Development description does not provide information about the number of workers involved in the project.)
# RAW RESPONSE: 45
# RAW RESPONSE: 30
# RAW RESPONSE: 20
# RAW RESPONSE: 30+
# RAW RESPONSE: None (The Workforce Development description does not provide a direct number for the number of workers involved in the project.)
# RAW RESPONSE: 6-8
# RAW RESPONSE: None (insufficient information)
# RAW RESPONSE: 2
# RAW RESPONSE: 100
# RAW RESPONSE: None (as the number of workers isn't specified directly)
# RAW RESPONSE: None (as no specific number of workers is mentioned directly related to this tree planting project)
# RAW RESPONSE: None (No specific number of workers is mentioned directly related to the 20 trees planting)
# RAW RESPONSE: 50
# RAW RESPONSE: None (insufficient information to estimate the number of workers)
# RAW RESPONSE: None (Insufficient information)
